# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col,explode
from pyspark.sql import SQLContext
import pyspark.sql.functions as sqlf
from pyspark.sql.functions import col
from pyspark.sql.functions import collect_list, struct, sort_array, broadcast
from pyspark.sql.functions import array_contains
from pyspark.sql.functions import udf
from pyspark.sql.functions import lit
from pyspark.sql.types import *
import pyspark.pandas as pd
import geopandas as gp
import numpy as np
from pyspark.sql import functions as F

# %%
# prevent string show as binary byte
#!spark-shell --conf spark.sql.parquet.binaryAsString=true

spark.conf.set("spark.sql.parquet.binaryAsString","true")

# %%
# %%time
# load the node parquet file into dataframe
parquet_path = ['/greater-london-latest.osm.pbf.node.parquet', '/centro-latest.osm.pbf.node.parquet', \
                '/ile-de-france-latest.osm.pbf.node.parquet', '/ontario-latest.osm.pbf.node.parquet']
london_node_df = sqlContext.read.parquet(parquet_path[0])
rome_node_df = sqlContext.read.parquet(parquet_path[1])
paris_node_df = sqlContext.read.parquet(parquet_path[2])
toronto_node_df = sqlContext.read.parquet(parquet_path[3])
# Out:
# CPU times: user 8.61 ms, sys: 0 ns, total: 8.61 ms
# Wall time: 4.81 s

# %% [markdown]
# <h3>Part.1 Test How Partition Impact Large Scale DF Performance<h3>

# %%
# test how partition could impact performance in large scale data
london_node_df_test = london_node_df.withColumn("partition_id", lit(1))
rome_node_df_test = rome_node_df.withColumn("partition_id", lit(2))
paris_node_df_test = paris_node_df.withColumn("partition_id", lit(3))
toronto_node_df_test = toronto_node_df.withColumn("partition_id", lit(4))

# %%
# as file size goes up, the partitions goes up
print("london: ", london_node_df.rdd.getNumPartitions()) 
print("rome: ", rome_node_df.rdd.getNumPartitions()) 
print("paris: ", paris_node_df.rdd.getNumPartitions()) 
print("toronto: ", toronto_node_df.rdd.getNumPartitions()) 
london_node_df.groupBy(F.spark_partition_id()).count().show()
rome_node_df.groupBy(F.spark_partition_id()).count().show()
paris_node_df.groupBy(F.spark_partition_id()).count().show()
toronto_node_df.groupBy(F.spark_partition_id()).count().show()
# Out:
# london:  2
# rome:  7
# paris:  5
# toronto:  17
# +--------------------+-------+
# |SPARK_PARTITION_ID()|  count|
# +--------------------+-------+
# |                   0|5740100|
# |                   1|3426086|
# +--------------------+-------+
# +--------------------+--------+
# |SPARK_PARTITION_ID()|   count|
# +--------------------+--------+
# |                   0| 5950100|
# |                   1| 5200100|
# |                   2| 6130100|
# |                   3| 6420100|
# |                   4|11374504|
# |                   5| 6130319|
# +--------------------+--------+
# +--------------------+-------+
# |SPARK_PARTITION_ID()|  count|
# +--------------------+-------+
# |                   0|6000100|
# |                   1|6140100|
# |                   2|5720100|
# |                   3|5980100|
# |                   4|4887681|
# +--------------------+-------+
# [Stage 56:====================================================>   (16 + 1) / 17]
# +--------------------+--------+
# |SPARK_PARTITION_ID()|   count|
# +--------------------+--------+
# |                   0| 6010100|
# |                   1| 4380100|
# |                   2| 6000100|
# |                   3|11240200|
# |                   4| 6550100|
# |                   5| 6670100|
# |                   6| 6540100|
# |                   7| 6670100|
# |                   8| 6680100|
# |                   9| 6530100|
# |                  10| 6540100|
# |                  11| 4058022|
# |                  12| 6270100|
# |                  13|13190200|
# |                  14| 6520100|
# |                  15| 5760100|
# |                  16| 2550609|
# +--------------------+--------+

# %%
# combine the original partition by city and df
combined_node_df = london_node_df.union(rome_node_df).union(paris_node_df).union(toronto_node_df)
combined_node_df.show(5)
print("combined partitions: ", combined_node_df.rdd.getNumPartitions()) 
combined_node_df.groupBy(F.spark_partition_id()).count().show()
# Out:
# +-----+-------+-------------+---------+---+--------+--------------------+------------------+--------------------+
# |   id|version|    timestamp|changeset|uid|user_sid|                tags|          latitude|           longitude|
# +-----+-------+-------------+---------+---+--------+--------------------+------------------+--------------------+
# |78112|      3|1539614984000|        0|  0|        |                  []|51.526976000000005|-0.14579240000000002|
# |99878|      9|1607700514000|        0|  0|        |[{access, permiss...| 51.52435800000001|          -0.1529847|
# |99879|      5|1596536339000|        0|  0|        |                  []|        51.5248246|          -0.1532934|
# |99880|      6|1635619078000|        0|  0|        |[{crossing, unmar...|        51.5250847|          -0.1535802|
# |99882|      1|1117060261000|        0|  0|        |                  []|51.525650000000006|          -0.1541197|
# +-----+-------+-------------+---------+---+--------+--------------------+------------------+--------------------+
# only showing top 5 rows
#
# combined partitions:  31
# [Stage 60:======================================================> (30 + 1) / 31]
# +--------------------+--------+
# |SPARK_PARTITION_ID()|   count|
# +--------------------+--------+
# |                   0| 5740100|
# |                   1| 3426086|
# |                   2| 5950100|
# |                   3| 5200100|
# |                   4| 6130100|
# |                   5| 6420100|
# |                   6|11374504|
# |                   7| 6130319|
# |                   9| 6000100|
# |                  10| 6140100|
# |                  11| 5720100|
# |                  12| 5980100|
# |                  13| 4887681|
# |                  14| 6010100|
# |                  15| 4380100|
# |                  16| 6000100|
# |                  17|11240200|
# |                  18| 6550100|
# |                  19| 6670100|
# |                  20| 6540100|
# +--------------------+--------+
# only showing top 20 rows

# %%
spark.conf.set("spark.sql.adaptive.enabled",False)

# %%
# Test repartition evenly, because repartition store in memory, need to reload from HDFS
combined_node_df_test = london_node_df_test.union(rome_node_df_test).union(paris_node_df_test).union(toronto_node_df_test)
combined_node_df_test = combined_node_df_test.repartition(31)
combined_node_df_test.write.mode("overwrite").parquet("/combined_filtered_parquet_test_large")
combined_node_df_test = sqlContext.read.parquet("/combined_filtered_parquet_test_large")
print("combined repartitioned: ", combined_node_df_test.rdd.getNumPartitions()) 
combined_node_df_test.groupBy(F.spark_partition_id()).count().show()
# Out:
# combined repartitioned:  47
# +--------------------+-------+
# |SPARK_PARTITION_ID()|  count|
# +--------------------+-------+
# |                  31|3239144|
# |                  34|3239142|
# |                  28|4550100|
# |                  26|4550100|
# |                  27|4550100|
# |                  44|3239146|
# |                  12|4550100|
# |                  22|4550100|
# |                   1|4550100|
# |                  13|4550100|
# |                   6|4550100|
# |                  16|4550100|
# |                   3|4550100|
# |                  20|4550100|
# |                  40|3239143|
# |                   5|4550100|
# |                  19|4550100|
# |                  41|3239144|
# |                  15|4550100|
# |                  43|3239141|
# +--------------------+-------+
# only showing top 20 rows

# %%
# to limit the city range by coordinate pairs from  {cityname: [lon, lat, lon, lat]} which is pair of left bottom and right top boundaries
# also serves to test how partition perform under same task
city_tag = {'london': [-0.483,51.385,0.233,51.609], 'toronto': [-79.69,43.602,-79.101,43.847], 'paris': [2.062,48.725,2.549,48.967], 'rome': [12.212,41.785,12.702,41.997]}

# if the location is in the city bounderis, then return the city name
def label_city(lat, lon):
    for k,v in city_tag.items():
        if lat > v[1] and lat < v[3] and lon < v[2] and lon > v[0]: 
            return k
    return ''

city_udf = udf(label_city, StringType())
city_name = ['london', 'toronto', 'paris', 'rome']

# %%
# %%time
# filter each location by given bounderies and give a city label on repartitioned combined df
partition_test1 = combined_node_df_test.withColumn('City', city_udf('latitude', 'longitude'))
partition_test1 = partition_test1.filter(partition_test1.City.isin(city_name))
partition_test1.show(1)
# Out:
# [Stage 75:>                                                         (0 + 1) / 1]
# +----------+-------+-------------+---------+---+--------+----+----------+---------+------------+------+
# |        id|version|    timestamp|changeset|uid|user_sid|tags|  latitude|longitude|partition_id|  City|
# +----------+-------+-------------+---------+---+--------+----+----------+---------+------------+------+
# |8365819648|      1|1611709599000|        0|  0|        |  []|51.5148706|0.1952346|           1|london|
# +----------+-------+-------------+---------+---+--------+----+----------+---------+------------+------+
# only showing top 1 row
#
# CPU times: user 10.4 ms, sys: 365 µs, total: 10.7 ms
# Wall time: 1.14 s

# %%
# %%time
# filter each location by given bounderies and give a city label on orinial combined df
partition_test2 = combined_node_df.withColumn('City', city_udf('latitude', 'longitude'))
partition_test2 = partition_test2.filter(partition_test2.City.isin(city_name))
partition_test2.show(1)
# Out:
# +-----+-------+-------------+---------+---+--------+----+------------------+--------------------+------+
# |   id|version|    timestamp|changeset|uid|user_sid|tags|          latitude|           longitude|  City|
# +-----+-------+-------------+---------+---+--------+----+------------------+--------------------+------+
# |78112|      3|1539614984000|        0|  0|        |  []|51.526976000000005|-0.14579240000000002|london|
# +-----+-------+-------------+---------+---+--------+----+------------------+--------------------+------+
# only showing top 1 row
#
# CPU times: user 0 ns, sys: 4.78 ms, total: 4.78 ms
# Wall time: 794 ms

# %% [markdown]
# <h3>Part.2 Preprocessing The Data<h3>

# %%
# check the scale of data
combined_node_df.printSchema()
n = combined_node_df.count()
print("all city: ", n)
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- version: integer (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- changeset: long (nullable = true)
#  |-- uid: integer (nullable = true)
#  |-- user_sid: string (nullable = true)
#  |-- tags: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- key: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
# [Stage 5:=======================================================> (30 + 1) / 31]
# all city:  191259821

# %%
# %%time
# filter out the location where has tags of tourism
combined_node_df_new = combined_node_df.filter(array_contains(combined_node_df.tags['key'], 'tourism'))
combined_node_df_new.show()
# Out:
# [Stage 8:>                                                          (0 + 1) / 1]
# +--------+-------+-------------+---------+---+--------+--------------------+------------------+--------------------+
# |      id|version|    timestamp|changeset|uid|user_sid|                tags|          latitude|           longitude|
# +--------+-------+-------------+---------+---+--------+--------------------+------------------+--------------------+
# |  388826|      4|1597920001000|        0|  0|        |[{board_type, wil...|51.530421000000004|          -0.1558246|
# |16960853|     10|1611135318000|        0|  0|        |[{amenity, founta...|51.409926500000005|          -0.3362121|
# |23723987|      5|1603822099000|        0|  0|        |[{information, gu...|51.636484100000004|           -0.151569|
# |23724048|      5|1603822099000|        0|  0|        |[{information, ma...|        51.6362223|-0.15106850000000002|
# |25507023|     14|1686861832000|        0|  0|        |[{alt_name, Spenc...|51.504848900000006|           -0.126149|
# |25508657|     11|1693655599000|        0|  0|        |[{artwork_type, s...|51.522035100000004|-0.12267080000000001|
# |25508658|      8|1450730542000|        0|  0|        |[{artwork_type, s...|        51.5217357|          -0.1224809|
# |25947730|      2|1683280359000|        0|  0|        |[{brand, Novotel}...|        51.4975442|          -0.4558534|
# |26559743|      3|1384169737000|        0|  0|        |[{tourism, attrac...|        51.3952047|          -0.1452455|
# |27084532|     13|1634575104000|        0|  0|        |[{artist_name, Ja...|51.505467200000005|          -0.0223917|
# |27408513|      5|1553292737000|        0|  0|        |[{name, Pitzhange...|        51.5108862|           -0.307107|
# |29269886|     44|1705523098000|        0|  0|        |[{addr:city, Lond...|        51.5228224|-0.15477680000000002|
# |29372721|      2|1245280208000|        0|  0|        |[{created_by, JOS...|        51.4170299|           0.0372264|
# |30151402|     11|1711412156000|        0|  0|        |[{artist_name, An...|        51.4527232|          -0.0203988|
# |30151952|     11|1711412238000|        0|  0|        |[{artist_name, Jo...|        51.4395462|-0.02620090000000...|
# |30152199|      9|1711412321000|        0|  0|        |[{artist_name, Jo...|        51.4260042|          -0.0333726|
# |31314241|     28|1705338684000|        0|  0|        |[{addr:city, Lond...|51.514571000000004|          -0.1566381|
# |31452361|     11|1686878323000|        0|  0|        |[{addr:city, Lond...|        51.4697472|-0.07007730000000001|
# |35123482|      8|1696845763000|        0|  0|        |[{artist_name, Da...|        51.5031722|-0.00147270000000...|
# |35127673|      6|1696845981000|        0|  0|        |[{artist_name, Jo...|        51.5089966|           0.0924925|
# +--------+-------+-------------+---------+---+--------+--------------------+------------------+--------------------+
# only showing top 20 rows
#
# CPU times: user 5.69 ms, sys: 0 ns, total: 5.69 ms
# Wall time: 1.9 s

# %%
# number of data that is tourism related
n = combined_node_df_new.count()
print("tourism spot: ", n)
# Out:
# [Stage 9:=======================================================> (30 + 1) / 31]
# tourism spot:  55382

# %%
# reduce the column
combined_node_df_filtered = combined_node_df_new.select(col("id"), col("latitude"), col("longitude"), col("tags"))
combined_node_df_filtered.show(20, False)
# Out:
# +--------+------------------+----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |id      |latitude          |longitude             |tags                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +--------+------------------+----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |388826  |51.530421000000004|-0.1558246            |[{board_type, wildlife}, {information, board}, {tourism, information}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |16960853|51.409926500000005|-0.3362121            |[{amenity, fountain}, {artwork_type, statue}, {name, Diana Fountain}, {tourism, artwork}, {wikidata, Q5271155}, {wikipedia, en:Diana Fountain, Bushy Park}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |23723987|51.636484100000004|-0.151569             |[{information, guidepost}, {tourism, information}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |23724048|51.6362223        |-0.15106850000000002  |[{information, map}, {name, Oak Hill Park}, {tourism, information}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |25507023|51.504848900000006|-0.126149             |[{alt_name, Spencer Compton, 8th Duke of Devonshire}, {artwork_type, statue}, {material, bronze}, {name, Spencer Compton}, {subject:wikidata, Q334063}, {subject:wikipedia, en:Spencer Cavendish, 8th Duke of Devonshire}, {tourism, artwork}, {wikidata, Q18176770}, {wikipedia, en:Statue of the Duke of Devonshire, Whitehall}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |25508657|51.522035100000004|-0.12267080000000001  |[{artwork_type, statue}, {description, maybe a queen}, {tourism, artwork}, {wheelchair, yes}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |25508658|51.5217357        |-0.1224809            |[{artwork_type, statue}, {description, mother and baby}, {tourism, artwork}, {wheelchair, yes}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |25947730|51.4975442        |-0.4558534            |[{brand, Novotel}, {brand:wikidata, Q420545}, {name, Novotel}, {tourism, hotel}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |26559743|51.3952047        |-0.1452455            |[{tourism, attraction}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |27084532|51.505467200000005|-0.0223917            |[{artist_name, James Horrobin & SOM}, {artwork_type, sculpture}, {level, 1}, {level:ref, 0}, {name, Cabot Square Railings}, {start_date, 1992}, {tourism, artwork}, {website, https://canarywharf.com/artwork/james-horrobin-som-cabot-square-railings/}, {wheelchair, yes}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |27408513|51.5108862        |-0.307107             |[{name, Pitzhanger Manor House and Gallery}, {tourism, museum}, {website, https://www.pitzhanger.org.uk/}, {wikidata, Q2097388}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |29269886|51.5228224        |-0.15477680000000002  |[{addr:city, London}, {addr:housenumber, 8-10}, {addr:postcode, NW1 5LR}, {addr:street, Marylebone Road}, {email, guest.experience@madame-tussauds.com}, {fee, yes}, {fhrs:confidence_management, 10}, {fhrs:hygiene, 5}, {fhrs:id, 428012}, {fhrs:local_authority_id, 01066/4000/0/000}, {fhrs:rating, 4}, {fhrs:structural, 5}, {name, Madame Tussauds}, {name:en, Madame Tussauds}, {name:ru, Мадам Тюссо}, {name:zh, 杜莎夫人蜡像馆}, {opening_hours, Mo-Fr 09:30-17:30; Sa-Su 09:00-18:00}, {phone, +44 871 894 3000}, {source:addr, FSA Food Hygiene Ratings Database}, {source:postcode, FSA Food Hygiene Ratings Database}, {toilets:wheelchair, yes}, {tourism, museum}, {website, https://www.madametussauds.co.uk/london}, {wheelchair, yes}, {wheelchair:description, Bis auf die Bustour am Ende kann man sich alles ansehen. Und wenn man Hilfe braucht um sich mit einer Figur fotografieren zu lassen sind die Mitarbeiter zur Stelle.}, {wikidata, Q186309}, {wikipedia, en:Madame Tussauds}]|
# |29372721|51.4170299        |0.0372264             |[{created_by, JOSM}, {name, Sundridge Park hotel and conference Ctr}, {tourism, hotel}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |30151402|51.4527232        |-0.0203988            |[{artist_name, Andrew Rowe}, {artwork_type, sculpture}, {bicycle, yes}, {cycle_network, UK:National Cycle Network}, {description, Sustrans Millennium Milepost for National Cycle Route 21, indicating north to Ladywell & Lewisham, east to Rushey Green, and south to Catford & Lower Sydenham.}, {destination, Catford;Rushey Green;Lower Sydenham;Lewisham;Ladywell}, {direction, 110}, {guide_type, destination}, {image, https://www.cyclestreets.net/location/186484/cyclestreets186484-size640.jpg}, {information, guidepost}, {material, metal}, {name, Millennium Milepost Ladywell Fields}, {ncn_milepost, rowe}, {operator, Sustrans}, {sustrans_ref, MP 244}, {tourism, information}, {website, https://www.sustrans.org.uk/national-cycle-network/millennium-mileposts/}]                                                                                                                                                                                                                       |
# |30151952|51.4395462        |-0.026200900000000003 |[{artist_name, Jon Mills}, {artwork_type, sculpture}, {bicycle, yes}, {cycle_network, UK:National Cycle Network}, {description, Sustrans Millennium Milepost for National Cycle Network route 21, indicating north to Catford (½mile) and Lewisham (1¾ miles) and south to Lower Sydenham (1 mile) and New Beckenham (1½ miles)}, {destination, Lower Beckenham;New Beckenham;Catford;Lewisham}, {direction, 90}, {guide_type, destination}, {image, https://www.cyclestreets.net/location/186483/cyclestreets186483-size640.jpg}, {information, guidepost}, {material, metal}, {name, Millennium Milepost Catford}, {ncn_milepost, mills}, {operator, Sustrans}, {sustrans_ref, MP 245}, {tourism, information}, {website, https://www.sustrans.org.uk/national-cycle-network/millennium-mileposts/}]                                                                                                                                                                                                        |
# |30152199|51.4260042        |-0.0333726            |[{artist_name, John Mills}, {artwork_type, sculpture}, {bicycle, yes}, {cycle_network, UK:National Cycle Network}, {description, Sustrans Millennium Milepost for National Cycle Network route 21, indication north to Catford (1½ miles )and Ladywell (2 miles) and south to New Beckenham (½ mile) and Kent House (1 mile)}, {destination, Catford;Ladywell;New Beckenham;Kent House}, {direction, 270}, {guide_type, destination}, {image, https://www.cyclestreets.net/location/186482/cyclestreets186482-size640.jpg}, {information, guidepost}, {material, metal}, {name, Millennium Milepost Bell Green}, {ncn_milepost, mills}, {operator, Sustrans}, {sustrans_ref, MP246}, {tourism, information}, {website, https://www.sustrans.org.uk/national-cycle-network/millennium-mileposts}]                                                                                                                                                                                                              |
# |31314241|51.514571000000004|-0.1566381            |[{addr:city, London}, {addr:housenumber, 4}, {addr:postcode, W1H 7BY}, {addr:street, Bryanston Street}, {brand, DoubleTree}, {brand:wikidata, Q2504643}, {contact:facebook, http://www.facebook.com/DoubleTreeByHiltonMarbleArch}, {email, doubletreelondonmarblearch.reservations@hilton.com}, {fax, +44 20 7487 2759}, {internet_access, yes}, {name, DoubleTree by Hilton Hotel London - Marble Arch}, {official_name, DoubleTree by Hilton}, {operator, Hilton}, {phone, +44 20 7935 2361}, {rooms, 122}, {smoking, no}, {stars, 4}, {tourism, hotel}, {website, https://www.hilton.com/en/hotels/lonmadi-doubletree-london-marble-arch/?WT.mc_id=zELWAKN0EMEA1DT2DMH3LocalSearch4DGGenericx6LONMADI}, {wheelchair, yes}, {wikidata, Q30504052}]                                                                                                                                                                                                                                                          |
# |31452361|51.4697472        |-0.07007730000000001  |[{addr:city, London}, {addr:housenumber, 21}, {addr:postcode, SE15 4QL}, {addr:street, Blenheim Grove}, {description, The Sassoon Gallery is behind Bar Story, and shows are open from 12-6pm.}, {name, The Sassoon Gallery}, {tourism, gallery}, {website, http://www.thesassoongallery.co.uk}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |35123482|51.5031722        |-0.0014727000000000002|[{artist_name, David Dudgeon}, {description, 1) Thames Barrier 2\n2) Waterloo Station 9 1/2\n\nThis milepost also has some additional text:\n\nThis milepost stands on the Greenwich meridian}, {image, https://www.cyclestreets.net/location/185535/cyclestreets185535.jpg}, {information, guidepost}, {name, Millennium Milepost O2 Arena}, {ncn_milepost, dudgeon}, {sustrans_ref, MP 713}, {tourism, information}, {website, https://www.sustrans.org.uk/national-cycle-network/millennium-mileposts/}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |35127673|51.5089966        |0.0924925             |[{artist_name, Jon Mills}, {artwork_type, sculpture}, {bicycle, yes}, {description, Sustrans Millenium Milepost for National Cycle Network route 1, indicating west (upstream along the Thames Path) for Inverness (1191 miles) and Greenwich (7 miles) and east (downstream along the Thames Path) for Dover (106 miles) and Dartford (10 miles)}, {destination, Inverness;Greenwich;Dover;Dartford}, {direction, 160}, {guide_type, destination}, {image, https://www.cyclestreets.net/location/185536/cyclestreets185536.jpg}, {information, guidepost}, {material, metal}, {name, Millennium Milepost Tripcock Point}, {ncn_milepost, mills}, {operator, Sustrans}, {sustrans_ref, MP 595}, {tourism, information}, {website, https://www.sustrans.org.uk/national-cycle-network/millennium-mileposts/}]                                                                                                                                                                                                  |
# +--------+------------------+----------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
# extract the name and tourism tag out of other tags.
def get_info(tags_string):
    info = ["", ""]
    for k, v in tags_string:
        if k == 'name':
            info[0] = v
        if k == 'tourism':
            info[1] = v
    return info

# %%
# %%time

# get the name and tourism info out of tags
udf_get_info = udf(lambda x: get_info(x), ArrayType(StringType(), True))
combined_node_df_filtered2 = combined_node_df_filtered.withColumn("name", udf_get_info("tags")[0]).withColumn("tourism_type", udf_get_info("tags")[1]).drop("tags")
combined_node_df_filtered2.show()
# Out:
# [Stage 13:>                                                         (0 + 1) / 1]
# +--------+------------------+--------------------+--------------------+------------+
# |      id|          latitude|           longitude|                name|tourism_type|
# +--------+------------------+--------------------+--------------------+------------+
# |  388826|51.530421000000004|          -0.1558246|                    | information|
# |16960853|51.409926500000005|          -0.3362121|      Diana Fountain|     artwork|
# |23723987|51.636484100000004|           -0.151569|                    | information|
# |23724048|        51.6362223|-0.15106850000000002|       Oak Hill Park| information|
# |25507023|51.504848900000006|           -0.126149|     Spencer Compton|     artwork|
# |25508657|51.522035100000004|-0.12267080000000001|                    |     artwork|
# |25508658|        51.5217357|          -0.1224809|                    |     artwork|
# |25947730|        51.4975442|          -0.4558534|             Novotel|       hotel|
# |26559743|        51.3952047|          -0.1452455|                    |  attraction|
# |27084532|51.505467200000005|          -0.0223917|Cabot Square Rail...|     artwork|
# |27408513|        51.5108862|           -0.307107|Pitzhanger Manor ...|      museum|
# |29269886|        51.5228224|-0.15477680000000002|     Madame Tussauds|      museum|
# |29372721|        51.4170299|           0.0372264|Sundridge Park ho...|       hotel|
# |30151402|        51.4527232|          -0.0203988|Millennium Milepo...| information|
# |30151952|        51.4395462|-0.02620090000000...|Millennium Milepo...| information|
# |30152199|        51.4260042|          -0.0333726|Millennium Milepo...| information|
# |31314241|51.514571000000004|          -0.1566381|DoubleTree by Hil...|       hotel|
# |31452361|        51.4697472|-0.07007730000000001| The Sassoon Gallery|     gallery|
# |35123482|        51.5031722|-0.00147270000000...|Millennium Milepo...| information|
# |35127673|        51.5089966|           0.0924925|Millennium Milepo...| information|
# +--------+------------------+--------------------+--------------------+------------+
# only showing top 20 rows
#
# CPU times: user 7.53 ms, sys: 1.71 ms, total: 9.24 ms
# Wall time: 4.68 s

# %%
# refine the quality of tourism spot, since many are low quality tourism tag
tourism_list = ["aquarium", "attraction", "gallery", "cathedral", "castle", "historical building", "monument", "museum", "theme_park", "zoo", "viewpoint"]
combined_node_df_filtered3 = combined_node_df_filtered2.filter(combined_node_df_filtered2['tourism_type'].isin(tourism_list))
combined_node_df_filtered3.show()
n = combined_node_df_filtered3.count()
print("filtered tourism spots", n)
# Out:
# +---------+------------------+--------------------+--------------------+------------+
# |       id|          latitude|           longitude|                name|tourism_type|
# +---------+------------------+--------------------+--------------------+------------+
# | 26559743|        51.3952047|          -0.1452455|                    |  attraction|
# | 27408513|        51.5108862|           -0.307107|Pitzhanger Manor ...|      museum|
# | 29269886|        51.5228224|-0.15477680000000002|     Madame Tussauds|      museum|
# | 31452361|        51.4697472|-0.07007730000000001| The Sassoon Gallery|     gallery|
# | 37124475|        51.3650663|-0.16684290000000002|Carshalton Water ...|      museum|
# |243762168|        51.4765054|          -0.0046057|                    |   viewpoint|
# |248617998|        51.5010897|          -0.0404578|          Stave Hill|   viewpoint|
# |252602371|51.506387800000006|-0.08826410000000001|London Bridge Exp...|  attraction|
# |253801699|        51.5777464|           -0.482696|                    |   viewpoint|
# |261700004|51.473607300000005|          -0.1155806|     The Type Museum|      museum|
# |262289990|        51.5293038|          -0.0062931|                    |   viewpoint|
# |266843474|        51.5028354|          -0.1185929|     London Aquarium|    aquarium|
# |266976402|        51.5400937|          -0.3732401|                    |   viewpoint|
# |268039103|51.596594700000004|          -0.1942691| Stephens Collection|      museum|
# |269236138|        51.3553025|          -0.1706494|Little Holland House|  attraction|
# |293221901|         51.448185|           0.1602259|Hall Place and Ga...|  attraction|
# |301471453|51.447687800000004|          -0.0676187|                    |   viewpoint|
# |310527489|51.622680700000004|          -0.2356185|           Millfield|   viewpoint|
# |321506811|51.536211400000006|           -0.127826|     St Pancras Lock|  attraction|
# |331101736|        51.5581844|-0.11811160000000001|    Nags Head Market|  attraction|
# +---------+------------------+--------------------+--------------------+------------+
# only showing top 20 rows
# [Stage 15:======================================================> (31 + 1) / 32]
# filtered tourism spots 8435

# %%
# to limit the city range by coordinate pairs from  {cityname: [lon, lat, lon, lat]} which is pair of left bottom and right top boundaries
city_tag = {'london': [-0.483,51.385,0.233,51.609], 'toronto': [-79.69,43.602,-79.101,43.847], 'paris': [2.062,48.725,2.549,48.967], 'rome': [12.212,41.785,12.702,41.997]}

# if the location is in the city bounderis, then return the city name
def label_city(lat, lon):
    for k,v in city_tag.items():
        if lat > v[1] and lat < v[3] and lon < v[2] and lon > v[0]: 
            return k
    return ''

city_udf = udf(label_city, StringType())

# %%
# give each location that are within the given bounderies a city label
city_name = ['london', 'toronto', 'paris', 'rome']
df = combined_node_df_filtered3.withColumn('City', city_udf('latitude', 'longitude'))
df = df.filter(df.City.isin(city_name))
df.show()
# Out:
# [Stage 18:>                                                         (0 + 1) / 1]
# +---------+------------------+--------------------+--------------------+------------+------+
# |       id|          latitude|           longitude|                name|tourism_type|  City|
# +---------+------------------+--------------------+--------------------+------------+------+
# | 26559743|        51.3952047|          -0.1452455|                    |  attraction|london|
# | 27408513|        51.5108862|           -0.307107|Pitzhanger Manor ...|      museum|london|
# | 29269886|        51.5228224|-0.15477680000000002|     Madame Tussauds|      museum|london|
# | 31452361|        51.4697472|-0.07007730000000001| The Sassoon Gallery|     gallery|london|
# |243762168|        51.4765054|          -0.0046057|                    |   viewpoint|london|
# |248617998|        51.5010897|          -0.0404578|          Stave Hill|   viewpoint|london|
# |252602371|51.506387800000006|-0.08826410000000001|London Bridge Exp...|  attraction|london|
# |253801699|        51.5777464|           -0.482696|                    |   viewpoint|london|
# |261700004|51.473607300000005|          -0.1155806|     The Type Museum|      museum|london|
# |262289990|        51.5293038|          -0.0062931|                    |   viewpoint|london|
# |266843474|        51.5028354|          -0.1185929|     London Aquarium|    aquarium|london|
# |266976402|        51.5400937|          -0.3732401|                    |   viewpoint|london|
# |268039103|51.596594700000004|          -0.1942691| Stephens Collection|      museum|london|
# |293221901|         51.448185|           0.1602259|Hall Place and Ga...|  attraction|london|
# |301471453|51.447687800000004|          -0.0676187|                    |   viewpoint|london|
# |321506811|51.536211400000006|           -0.127826|     St Pancras Lock|  attraction|london|
# |331101736|        51.5581844|-0.11811160000000001|    Nags Head Market|  attraction|london|
# |334631276|51.523372200000004|-0.11620910000000001|      Dickens Museum|      museum|london|
# |336347265|        51.5566742|          -0.1081434|      Arsenal Museum|      museum|london|
# |336351665|         51.578726|          -0.4275317|  Manor Farm Complex|      museum|london|
# +---------+------------------+--------------------+--------------------+------------+------+
# only showing top 20 rows

# %%
# Test partition by closer location could accelerate the clustering speed during ML
# check https://stackoverflow.com/questions/40416357/difference-between-df-repartition-and-dataframewriter-partitionby/42780452#42780452
df.write.partitionBy("City").mode("overwrite").parquet("/combined_filtered_parquet_bycity")

# %%
# Test partition by closer location could accelerate the clustering speed during ML
df.write.mode("overwrite").parquet("/combined_filtered_parquet_random")
